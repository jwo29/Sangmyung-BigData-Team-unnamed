# %%
import requests
import urllib.parse as urlparse
import json
import pandas as pd

# URL 만들기 함수
def get_request_query(operation1, operation2, params, serviceKey):
    URL = 'http://openapi.tago.go.kr/openapi/service'
    params = urlparse.urlencode(params)
    request_query = URL + '/' + operation1 + '/' + operation2 + '?' + params + '&' + 'ServiceKey' + '=' + serviceKey
    return request_query

# 요청 URL과 오퍼레이션
URL = 'http://openapi.tago.go.kr/openapi/service'

OPERATION1 = 'BusRouteInfoInqireService'
OPERATION2 = 'getRouteInfoIem' # 

# 서비스키
SERVICEKEY = "Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D"

# intervaltime = #배차간격(평일) ex)29 // 배차간격[분]
# intervalsattime = #배차간격(토요일) ex)23 // 배차간격(토요일)[분] 제공x
# intervalsuntime = #배차간격(일요일) ex)29 // 배차간격(일요일)[분] 제공x
bus_routes_data = pd.read_csv("route_id.csv")

bus_routes_schedule_data = pd.DataFrame(columns = ("routeid", "routeno", "startnodenm", "startvehicletime", "endnodenm", "endvehicletime", "intervaltime")) 

# 파라미터
cityCode  = 34010  # 
routeId = bus_routes_data["routeid"]
_type = "json"
numOfRows = 150
idx = 0

for idx in range(len(routeId)):
    
    PARAMS = {'cityCode':cityCode, 'routeId':routeId[idx], 'numOfRows': numOfRows, '_type': _type}

    # URL만들기
    request_query = get_request_query(OPERATION1, OPERATION2, PARAMS, SERVICEKEY)
    print('request_query:', request_query)

    # #GET
    response = requests.get(url = request_query)

    #상태 확인
    print('status_code:' + str(response.status_code))

    r_dict = json.loads(response.text)
    r_response = r_dict.get("response")
    r_body = r_response.get("body")
    r_items = r_body.get("items")
    r_item = r_items.get("item")

    print(r_item)

    routeid = r_item["routeid"]
    routeno = r_item["routeno"]
    startnodenm = r_item["startnodenm"]
    startvehicletime = r_item["startvehicletime"]
    endnodenm = r_item["endnodenm"]
    endvehicletime = r_item["endvehicletime"]
    intervaltime = r_item["intervaltime"]

    bus_routes_schedule_data.loc[idx] = [routeid, routeno, startnodenm, startvehicletime, endnodenm, endvehicletime,intervaltime]
# Out:
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000006&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '두정우남아파트', 'endvehicletime': 2230, 'intervaltime': 10, 'routeid': 'CAB285000006', 'routeno': 11, 'routetp': '일반버스', 'startnodenm': '두정우성아파트', 'startvehicletime': '0605'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000007&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '두정한성아파트', 'endvehicletime': 2230, 'intervaltime': 10, 'routeid': 'CAB285000007', 'routeno': 11, 'routetp': '일반버스', 'startnodenm': '두정우남아파트', 'startvehicletime': '0610'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000008&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '부영아파트', 'endvehicletime': 2230, 'intervaltime': 7, 'routeid': 'CAB285000008', 'routeno': 12, 'routetp': '일반버스', 'startnodenm': '방아다리공원', 'startvehicletime': '0604'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000009&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '방아다리공원', 'endvehicletime': 2222, 'intervaltime': 7, 'routeid': 'CAB285000009', 'routeno': 12, 'routetp': '일반버스', 'startnodenm': '부영아파트', 'startvehicletime': '0605'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000010&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '천안아산역', 'endvehicletime': 2230, 'intervaltime': 11, 'routeid': 'CAB285000010', 'routeno': 13, 'routetp': '일반버스', 'startnodenm': '단대병원', 'startvehicletime': '0600'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000011&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '단대병원', 'endvehicletime': 2245, 'intervaltime': 11, 'routeid': 'CAB285000011', 'routeno': 13, 'routetp': '일반버스', 'startnodenm': '천안아산역', 'startvehicletime': '0605'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000012&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '백석대학교(운동장)', 'endvehicletime': 2220, 'intervaltime': 10, 'routeid': 'CAB285000012', 'routeno': 14, 'routetp': '일반버스', 'startnodenm': '방아다리공원', 'startvehicletime': '0600'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000013&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '방아다리공원', 'endvehicletime': 2215, 'intervaltime': 10, 'routeid': 'CAB285000013', 'routeno': 14, 'routetp': '일반버스', 'startnodenm': '백석대학교(운동장)', 'startvehicletime': '0610'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000024&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '동우아파트', 'endvehicletime': 2230, 'intervaltime': 20, 'routeid': 'CAB285000024', 'routeno': 24, 'routetp': '일반버스', 'startnodenm': '각원사', 'startvehicletime': '0610'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000025&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '각원사', 'endvehicletime': 2225, 'intervaltime': 20, 'routeid': 'CAB285000025', 'routeno': 24, 'routetp': '일반버스', 'startnodenm': '동우아파트', 'startvehicletime': '0620'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000293&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '차암2통', 'endvehicletime': 2240, 'intervaltime': 20, 'routeid': 'CAB285000293', 'routeno': 81, 'routetp': '일반버스', 'startnodenm': '각원사', 'startvehicletime': '0620'}
# request_query: http://openapi.tago.go.kr/openapi/service/BusRouteInfoInqireService/getRouteInfoIem?cityCode=34010&routeId=CAB285000294&numOfRows=150&_type=json&ServiceKey=Ee5WLqN4iRCKuFUsxlAF1P9anyOX5vH%2BOFG2%2BYM%2BcEoNQOg9emMEyyKM37eAmmVnl1ZxgTalHHL90VNl1B1zlg%3D%3D
# status_code:200
# {'endnodenm': '각원사', 'endvehicletime': 2230, 'intervaltime': 20, 'routeid': 'CAB285000294', 'routeno': 81, 'routetp': '일반버스', 'startnodenm': '차암2통', 'startvehicletime': '0630'}

# %%
bus_routes_schedule_data.to_csv("route_info.csv", encoding='utf-8-sig')

# %%
bus_routes_schedule_data
# Out:
#          routeid routeno startnodenm startvehicletime   endnodenm  \
# 0   CAB285000006      11     두정우성아파트             0605     두정우남아파트
# 1   CAB285000007      11     두정우남아파트             0610     두정한성아파트
# 2   CAB285000008      12      방아다리공원             0604       부영아파트
# 3   CAB285000009      12       부영아파트             0605      방아다리공원
# 4   CAB285000010      13        단대병원             0600       천안아산역
# 5   CAB285000011      13       천안아산역             0605        단대병원
# 6   CAB285000012      14      방아다리공원             0600  백석대학교(운동장)
# 7   CAB285000013      14  백석대학교(운동장)             0610      방아다리공원
# 8   CAB285000024      24         각원사             0610       동우아파트
# 9   CAB285000025      24       동우아파트             0620         각원사
# 10  CAB285000293      81         각원사             0620        차암2통
# 11  CAB285000294      81        차암2통             0630         각원사
#
#    endvehicletime intervaltime
# 0            2230           10
# 1            2230           10
# 2            2230            7
# 3            2222            7
# 4            2230           11
# 5            2245           11
# 6            2220           10
# 7            2215           10
# 8            2230           20
# 9            2225           20
# 10           2240           20
# 11           2230           20
